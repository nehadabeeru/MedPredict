# %%
import pandas as pd
from datetime import timedelta
import matplotlib.pyplot as plt
import numpy as np

# %%
import re

# %%
# File paths
balanced_path = 'balance_data.csv'
balanced_data = pd.read_csv(balanced_path)

# %%
# Step 1: Replace separators to ensure consistent delimiter
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'[\\/]', ';', regex=True)
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r',', ';', regex=True)

# Step 2: Apply corrections for known misspellings and abbreviations
corrections = {
    r'\brenal failiure\b': 'renal failure',
    r'\baromegley\b': 'acromegaly',
    r'\bvf arrest\b': 'ventricular fibrillation arrest',
    r'\bs/p\b': 'status post',
    r'\bcath\b': 'catheterization',
    r'\bmi\b': 'myocardial infarction',
    r'\bchf\b': 'congestive heart failure',
    r'\boa\b': 'osteoarthritis'
}
for pattern, replacement in corrections.items():
    balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(pattern, replacement, regex=True)

# Step 3: Map similar diagnoses to standard terms using word boundaries to prevent partial matches
standard_terms = {
    r'\bsepsis\b': 'sepsis',
    r'\burinary tract infection\b|\buti\b': 'urinary tract infection',
    r'\bheart failure\b|\bcongestive heart failure\b': 'heart failure',
    r'\bstroke\b|\bcva\b|\btia\b': 'stroke',
    r'\bcopd\b|\bchronic obstructive pulmonary disease\b': 'COPD',
    r'\bkidney failure\b|\brenal failure\b': 'renal failure',
    r'\bventricular fibrillation arrest\b': 'cardiac arrest',
    r'\bhypertension\b|\bhigh blood pressure\b': 'hypertension',
    r'\bpneumonia\b': 'pneumonia',
    r'\bbrain metastasis\b|\bmetastatic brain tumor\b': 'brain metastasis',
    r'\bmyocardial infarction\b': 'myocardial infarction'
}
for pattern, replacement in standard_terms.items():
    balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(pattern, replacement, regex=True)

# Step 4: Remove extra spaces and set to lowercase
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'\s+', ' ', regex=True).str.strip().str.lower()

# Step 5: Remove duplicate diagnoses within each entry (e.g., "sepsis; sepsis" becomes "sepsis")
def remove_duplicates(diagnosis):
    conditions = diagnosis.split(';')
    unique_conditions = sorted(set([cond.strip() for cond in conditions if cond]))
    return '; '.join(unique_conditions)

balanced_data['diagnosis'] = balanced_data['diagnosis'].apply(remove_duplicates)

# Display unique values to verify
print(balanced_data['diagnosis'].unique())
# Out:
# ['sepsis' 'hepatitis b' 'humeral fracture' 'alcoholic hepatitis' 'stroke'
#  'coronary artery bypass graft with mvr ? mitral valve replacement; coronary artery disease; mitral regurgitation; sda'
#  'syncope; telemetry' 'right humerous fracture'
#  'renal failure-syncope-hyperkalemia'
#  'pre hydration; recurrent left carotid stenosis' 'failure to thrive'
#  'catheterization; pulmonary edema' 'unstable angina'
#  'respiratory distress' 'brain metastasis; metastatic melanoma' 'fever'
#  'brain metastases' 'lower gi bleed' 'catheterization; chest pain'
#  'p fall; s; subdural hematoma' 'esophageal cancer; sda'
#  'p motorcycle accident; s' 'seizure' 'gastrointestinal bleed'
#  'lung cancer; shortness of breath' 'hypotension' 'heart failure'
#  'urosepsis' 'basal ganglin bleed' 'overdose'
#  'critical aortic stenosis; hypotension' 'sepsis; telemetry'
#  'status post motor vehicle accident with injuries' 'tachypnea; telemetry'
#  'chronic myelogenous leukemia; transfusion reaction'
#  'hyponatremia; urinary tract infection' 'headache' 'cardiac arrest'
#  'myocardial infarction; pulmonary edema' 'liver failure'
#  'p motor vehicle accident; s' 'abscess' 'hypoxia; non small cell cancer'
#  'shortness of breath' 'pneumonia' 'acute cholangitis'
#  'fever; urinary tract infection'
#  'intracranial hemorrhage; syncope; telemetry'
#  'left hip osteoarthritis; sda' 'mediastinal adenopathy' 'facial numbness'
#  'acromegaly; burkitts lymphoma' 'stemi' 'tracheal esophageal fistula'
#  'cholecystitis' 'cellulitis' 'abdominal pain'
#  'asthma; chronic obst pulm disease'
#  'elevated liver functions; p liver transplant; s'
#  'pyelonephritis; urinary tract infection'
#  'sepsis; urinary tract infection' 'p fall; s' 'tracheal stenosis'
#  'catheterization; inferior myocardial infarction' 'hepatic encep'
#  'chest pain' 'renal cancer; sda' 'upper gi bleed'
#  'hypoglcemia; pneumonia; syncope' 'asthma; copd flare' 'volvulus'
#  'seizure; status epilepticus' 'hypoglycemia' 'cerebrovascular accident'
#  'anemia; metastic melanoma' 'hypotension; renal failure'
#  'acute subdural hematoma' 'esophageal ca; sda'
#  'myocardial infarction heart failure' 'pleural effusion'
#  'pneumonia; telemetry'
#  'coronary artery bypass graft; coronary artery disease; sda'
#  'pericardial effusion' 'altered mental status'
#  'acute renal failure; acute respiratory distress syndrome' 'bradycardia'
#  'cholangitis' 'hypotension; telemetry' 'acute pulmonary embolism'
#  'hypotension; unresponsive' 'left hip fracture' 'variceal bleed'
#  'acute cholecystitis' 'pneumonia; sepsis; telemetry']

# %%
# Further corrections for remaining abbreviations and fragments
additional_corrections = {
    r'\bp fall\b': 'fall',
    r'\bp motorcycle accident\b': 'motorcycle accident',
    r'\bp motor vehicle accident\b': 'motor vehicle accident',
    r'\bs\b': '',  # Remove standalone "s" entries left from partial replacements
    r'\bhypoglcemia\b': 'hypoglycemia',
    r'\bmetastic\b': 'metastatic'
}

# Apply additional corrections
for pattern, replacement in additional_corrections.items():
    balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(pattern, replacement, regex=True)

# Remove extra spaces and lowercase for final cleanup
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'\s+', ' ', regex=True).str.strip().str.lower()

# Verify the final unique values
print(balanced_data['diagnosis'].unique())
# Out:
# ['sepsis' 'hepatitis b' 'humeral fracture' 'alcoholic hepatitis' 'stroke'
#  'coronary artery bypass graft with mvr ? mitral valve replacement; coronary artery disease; mitral regurgitation; sda'
#  'syncope; telemetry' 'right humerous fracture'
#  'renal failure-syncope-hyperkalemia'
#  'pre hydration; recurrent left carotid stenosis' 'failure to thrive'
#  'catheterization; pulmonary edema' 'unstable angina'
#  'respiratory distress' 'brain metastasis; metastatic melanoma' 'fever'
#  'brain metastases' 'lower gi bleed' 'catheterization; chest pain'
#  'fall; ; subdural hematoma' 'esophageal cancer; sda'
#  'motorcycle accident;' 'seizure' 'gastrointestinal bleed'
#  'lung cancer; shortness of breath' 'hypotension' 'heart failure'
#  'urosepsis' 'basal ganglin bleed' 'overdose'
#  'critical aortic stenosis; hypotension' 'sepsis; telemetry'
#  'status post motor vehicle accident with injuries' 'tachypnea; telemetry'
#  'chronic myelogenous leukemia; transfusion reaction'
#  'hyponatremia; urinary tract infection' 'headache' 'cardiac arrest'
#  'myocardial infarction; pulmonary edema' 'liver failure'
#  'motor vehicle accident;' 'abscess' 'hypoxia; non small cell cancer'
#  'shortness of breath' 'pneumonia' 'acute cholangitis'
#  'fever; urinary tract infection'
#  'intracranial hemorrhage; syncope; telemetry'
#  'left hip osteoarthritis; sda' 'mediastinal adenopathy' 'facial numbness'
#  'acromegaly; burkitts lymphoma' 'stemi' 'tracheal esophageal fistula'
#  'cholecystitis' 'cellulitis' 'abdominal pain'
#  'asthma; chronic obst pulm disease'
#  'elevated liver functions; p liver transplant;'
#  'pyelonephritis; urinary tract infection'
#  'sepsis; urinary tract infection' 'fall;' 'tracheal stenosis'
#  'catheterization; inferior myocardial infarction' 'hepatic encep'
#  'chest pain' 'renal cancer; sda' 'upper gi bleed'
#  'hypoglycemia; pneumonia; syncope' 'asthma; copd flare' 'volvulus'
#  'seizure; status epilepticus' 'hypoglycemia' 'cerebrovascular accident'
#  'anemia; metastatic melanoma' 'hypotension; renal failure'
#  'acute subdural hematoma' 'esophageal ca; sda'
#  'myocardial infarction heart failure' 'pleural effusion'
#  'pneumonia; telemetry'
#  'coronary artery bypass graft; coronary artery disease; sda'
#  'pericardial effusion' 'altered mental status'
#  'acute renal failure; acute respiratory distress syndrome' 'bradycardia'
#  'cholangitis' 'hypotension; telemetry' 'acute pulmonary embolism'
#  'hypotension; unresponsive' 'left hip fracture' 'variceal bleed'
#  'acute cholecystitis' 'pneumonia; sepsis; telemetry']

# %%
# Remove trailing and isolated semicolons
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r';\s*$', '', regex=True)  # Remove trailing semicolons
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'\b;\b', '', regex=True)  # Remove isolated semicolons

# Additional corrections for remaining misspellings and specific cases
final_corrections = {
    r'\bbasal ganglin bleed\b': 'basal ganglia bleed',
    r'\bhypotension-syncope-hyperkalemia\b': 'hypotension; syncope; hyperkalemia',
    r'\besophageal ca\b': 'esophageal cancer',
    r'\binferior myocardial infarction\b': 'myocardial infarction',
    r'\bacromegly\b': 'acromegaly'
}

# Apply the final corrections
for pattern, replacement in final_corrections.items():
    balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(pattern, replacement, regex=True)

# Final whitespace cleanup
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'\s+', ' ', regex=True).str.strip().str.lower()

# Verify the final unique values
print(balanced_data['diagnosis'].unique())
# Out:
# ['sepsis' 'hepatitis b' 'humeral fracture' 'alcoholic hepatitis' 'stroke'
#  'coronary artery bypass graft with mvr ? mitral valve replacement; coronary artery disease; mitral regurgitation; sda'
#  'syncope; telemetry' 'right humerous fracture'
#  'renal failure-syncope-hyperkalemia'
#  'pre hydration; recurrent left carotid stenosis' 'failure to thrive'
#  'catheterization; pulmonary edema' 'unstable angina'
#  'respiratory distress' 'brain metastasis; metastatic melanoma' 'fever'
#  'brain metastases' 'lower gi bleed' 'catheterization; chest pain'
#  'fall; ; subdural hematoma' 'esophageal cancer; sda'
#  'motorcycle accident' 'seizure' 'gastrointestinal bleed'
#  'lung cancer; shortness of breath' 'hypotension' 'heart failure'
#  'urosepsis' 'basal ganglia bleed' 'overdose'
#  'critical aortic stenosis; hypotension' 'sepsis; telemetry'
#  'status post motor vehicle accident with injuries' 'tachypnea; telemetry'
#  'chronic myelogenous leukemia; transfusion reaction'
#  'hyponatremia; urinary tract infection' 'headache' 'cardiac arrest'
#  'myocardial infarction; pulmonary edema' 'liver failure'
#  'motor vehicle accident' 'abscess' 'hypoxia; non small cell cancer'
#  'shortness of breath' 'pneumonia' 'acute cholangitis'
#  'fever; urinary tract infection'
#  'intracranial hemorrhage; syncope; telemetry'
#  'left hip osteoarthritis; sda' 'mediastinal adenopathy' 'facial numbness'
#  'acromegaly; burkitts lymphoma' 'stemi' 'tracheal esophageal fistula'
#  'cholecystitis' 'cellulitis' 'abdominal pain'
#  'asthma; chronic obst pulm disease'
#  'elevated liver functions; p liver transplant'
#  'pyelonephritis; urinary tract infection'
#  'sepsis; urinary tract infection' 'fall' 'tracheal stenosis'
#  'catheterization; myocardial infarction' 'hepatic encep' 'chest pain'
#  'renal cancer; sda' 'upper gi bleed' 'hypoglycemia; pneumonia; syncope'
#  'asthma; copd flare' 'volvulus' 'seizure; status epilepticus'
#  'hypoglycemia' 'cerebrovascular accident' 'anemia; metastatic melanoma'
#  'hypotension; renal failure' 'acute subdural hematoma'
#  'myocardial infarction heart failure' 'pleural effusion'
#  'pneumonia; telemetry'
#  'coronary artery bypass graft; coronary artery disease; sda'
#  'pericardial effusion' 'altered mental status'
#  'acute renal failure; acute respiratory distress syndrome' 'bradycardia'
#  'cholangitis' 'hypotension; telemetry' 'acute pulmonary embolism'
#  'hypotension; unresponsive' 'left hip fracture' 'variceal bleed'
#  'acute cholecystitis' 'pneumonia; sepsis; telemetry']

# %%
# Dictionary of abbreviations to their full forms
abbreviation_mapping = {
    r'\bmvr\b': 'mitral valve replacement',
    r'\bcabg\b': 'coronary artery bypass graft',
    # Add other abbreviations if needed
}

# Replace abbreviations with their full forms
for abbr, full_form in abbreviation_mapping.items():
    balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(abbr, full_form, regex=True)

# Remove any lingering "?" and extra whitespace
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'\?', '', regex=True)
balanced_data['diagnosis'] = balanced_data['diagnosis'].str.replace(r'\s+', ' ', regex=True).str.strip().str.lower()

# Verify final unique values
print(balanced_data['diagnosis'].unique())
# Out:
# ['sepsis' 'hepatitis b' 'humeral fracture' 'alcoholic hepatitis' 'stroke'
#  'coronary artery bypass graft with mitral valve replacement mitral valve replacement; coronary artery disease; mitral regurgitation; sda'
#  'syncope; telemetry' 'right humerous fracture'
#  'renal failure-syncope-hyperkalemia'
#  'pre hydration; recurrent left carotid stenosis' 'failure to thrive'
#  'catheterization; pulmonary edema' 'unstable angina'
#  'respiratory distress' 'brain metastasis; metastatic melanoma' 'fever'
#  'brain metastases' 'lower gi bleed' 'catheterization; chest pain'
#  'fall; ; subdural hematoma' 'esophageal cancer; sda'
#  'motorcycle accident' 'seizure' 'gastrointestinal bleed'
#  'lung cancer; shortness of breath' 'hypotension' 'heart failure'
#  'urosepsis' 'basal ganglia bleed' 'overdose'
#  'critical aortic stenosis; hypotension' 'sepsis; telemetry'
#  'status post motor vehicle accident with injuries' 'tachypnea; telemetry'
#  'chronic myelogenous leukemia; transfusion reaction'
#  'hyponatremia; urinary tract infection' 'headache' 'cardiac arrest'
#  'myocardial infarction; pulmonary edema' 'liver failure'
#  'motor vehicle accident' 'abscess' 'hypoxia; non small cell cancer'
#  'shortness of breath' 'pneumonia' 'acute cholangitis'
#  'fever; urinary tract infection'
#  'intracranial hemorrhage; syncope; telemetry'
#  'left hip osteoarthritis; sda' 'mediastinal adenopathy' 'facial numbness'
#  'acromegaly; burkitts lymphoma' 'stemi' 'tracheal esophageal fistula'
#  'cholecystitis' 'cellulitis' 'abdominal pain'
#  'asthma; chronic obst pulm disease'
#  'elevated liver functions; p liver transplant'
#  'pyelonephritis; urinary tract infection'
#  'sepsis; urinary tract infection' 'fall' 'tracheal stenosis'
#  'catheterization; myocardial infarction' 'hepatic encep' 'chest pain'
#  'renal cancer; sda' 'upper gi bleed' 'hypoglycemia; pneumonia; syncope'
#  'asthma; copd flare' 'volvulus' 'seizure; status epilepticus'
#  'hypoglycemia' 'cerebrovascular accident' 'anemia; metastatic melanoma'
#  'hypotension; renal failure' 'acute subdural hematoma'
#  'myocardial infarction heart failure' 'pleural effusion'
#  'pneumonia; telemetry'
#  'coronary artery bypass graft; coronary artery disease; sda'
#  'pericardial effusion' 'altered mental status'
#  'acute renal failure; acute respiratory distress syndrome' 'bradycardia'
#  'cholangitis' 'hypotension; telemetry' 'acute pulmonary embolism'
#  'hypotension; unresponsive' 'left hip fracture' 'variceal bleed'
#  'acute cholecystitis' 'pneumonia; sepsis; telemetry']

# %%
# Function to remove duplicate phrases within each diagnosis
def remove_duplicate_phrases(diagnosis):
    phrases = diagnosis.split(';')
    unique_phrases = sorted(set([phrase.strip() for phrase in phrases if phrase.strip()]))
    return '; '.join(unique_phrases)

# Apply the function to the 'diagnosis' column
balanced_data['diagnosis'] = balanced_data['diagnosis'].apply(remove_duplicate_phrases)

# Verify the final unique values to confirm duplicates are removed
print(balanced_data['diagnosis'].unique())
# Out:
# ['sepsis' 'hepatitis b' 'humeral fracture' 'alcoholic hepatitis' 'stroke'
#  'coronary artery bypass graft with mitral valve replacement mitral valve replacement; coronary artery disease; mitral regurgitation; sda'
#  'syncope; telemetry' 'right humerous fracture'
#  'renal failure-syncope-hyperkalemia'
#  'pre hydration; recurrent left carotid stenosis' 'failure to thrive'
#  'catheterization; pulmonary edema' 'unstable angina'
#  'respiratory distress' 'brain metastasis; metastatic melanoma' 'fever'
#  'brain metastases' 'lower gi bleed' 'catheterization; chest pain'
#  'fall; subdural hematoma' 'esophageal cancer; sda' 'motorcycle accident'
#  'seizure' 'gastrointestinal bleed' 'lung cancer; shortness of breath'
#  'hypotension' 'heart failure' 'urosepsis' 'basal ganglia bleed'
#  'overdose' 'critical aortic stenosis; hypotension' 'sepsis; telemetry'
#  'status post motor vehicle accident with injuries' 'tachypnea; telemetry'
#  'chronic myelogenous leukemia; transfusion reaction'
#  'hyponatremia; urinary tract infection' 'headache' 'cardiac arrest'
#  'myocardial infarction; pulmonary edema' 'liver failure'
#  'motor vehicle accident' 'abscess' 'hypoxia; non small cell cancer'
#  'shortness of breath' 'pneumonia' 'acute cholangitis'
#  'fever; urinary tract infection'
#  'intracranial hemorrhage; syncope; telemetry'
#  'left hip osteoarthritis; sda' 'mediastinal adenopathy' 'facial numbness'
#  'acromegaly; burkitts lymphoma' 'stemi' 'tracheal esophageal fistula'
#  'cholecystitis' 'cellulitis' 'abdominal pain'
#  'asthma; chronic obst pulm disease'
#  'elevated liver functions; p liver transplant'
#  'pyelonephritis; urinary tract infection'
#  'sepsis; urinary tract infection' 'fall' 'tracheal stenosis'
#  'catheterization; myocardial infarction' 'hepatic encep' 'chest pain'
#  'renal cancer; sda' 'upper gi bleed' 'hypoglycemia; pneumonia; syncope'
#  'asthma; copd flare' 'volvulus' 'seizure; status epilepticus'
#  'hypoglycemia' 'cerebrovascular accident' 'anemia; metastatic melanoma'
#  'hypotension; renal failure' 'acute subdural hematoma'
#  'myocardial infarction heart failure' 'pleural effusion'
#  'pneumonia; telemetry'
#  'coronary artery bypass graft; coronary artery disease; sda'
#  'pericardial effusion' 'altered mental status'
#  'acute renal failure; acute respiratory distress syndrome' 'bradycardia'
#  'cholangitis' 'hypotension; telemetry' 'acute pulmonary embolism'
#  'hypotension; unresponsive' 'left hip fracture' 'variceal bleed'
#  'acute cholecystitis' 'pneumonia; sepsis; telemetry']

# %%
balanced_data.emergency_duration_label
# Out:
# 0      moderate duration of 6.283333333333333 hours
# 1                       short duration of 0.0 hours
# 2                       short duration of 0.0 hours
# 3      moderate duration of 7.616666666666666 hours
# 4                       short duration of 0.0 hours
#                            ...
# 231                 moderate duration of 7.65 hours
# 232    moderate duration of 4.183333333333334 hours
# 233                     short duration of 0.0 hours
# 234    moderate duration of 6.716666666666667 hours
# 235                 moderate duration of 7.65 hours
# Name: emergency_duration_label, Length: 236, dtype: object

# %%
# Round the duration to two decimal places and update the label
balanced_data['emergency_duration_label'] = balanced_data['emergency_duration_label'].apply(
    lambda x: ' '.join([x.split()[0], x.split()[1], "of", f"{float(x.split()[3]):.2f}", "hours"])
)

# Display a few rows to verify
print(balanced_data['emergency_duration_label'].head())
# Out:
# 0    moderate duration of 6.28 hours
# 1       short duration of 0.00 hours
# 2       short duration of 0.00 hours
# 3    moderate duration of 7.62 hours
# 4       short duration of 0.00 hours
# Name: emergency_duration_label, dtype: object

# %%
# Function to format emergency duration label
def format_duration_label(label):
    parts = label.split()
    duration = float(parts[3])
    if duration == 0.0:
        return "none"
    else:
        return f"{parts[0]} {parts[1]} of {duration:.2f} hours"

# Apply the function to update the column
balanced_data['emergency_duration_label'] = balanced_data['emergency_duration_label'].apply(format_duration_label)

# Display a few rows to verify the result
print(balanced_data['emergency_duration_label'].head())
# Out:
# 0    moderate duration of 6.28 hours
# 1                               none
# 2                               none
# 3    moderate duration of 7.62 hours
# 4                               none
# Name: emergency_duration_label, dtype: object

# %%
balanced_data.head(10)
# Out:
#    subject_id   hadm_id admission_type  \
# 0     10006.0  142345.0      emergency
# 1     10011.0  105331.0      emergency
# 2     10013.0  165520.0      emergency
# 3     10017.0  199207.0      emergency
# 4     10019.0  177759.0      emergency
# 5     10026.0  103770.0      emergency
# 6     10027.0  199395.0       elective
# 7     10029.0  132349.0      emergency
# 8     10032.0  140372.0      emergency
# 9     10033.0  157235.0      emergency
#
#                                   admission_location  \
# 0                           emergency room admission
# 1  transfer from another hospital or external fac...
# 2  transfer from another hospital or external fac...
# 3                           emergency room admission
# 4  transfer from another hospital or external fac...
# 5                           emergency room admission
# 6               physician referral / normal delivery
# 7                           emergency room admission
# 8                           emergency room admission
# 9                           emergency room admission
#
#                          discharge_location insurance marital_status  \
# 0                          home health care  medicare      separated
# 1                                  deceased   private         single
# 2                                  deceased  medicare        unknown
# 3                  skilled nursing facility  medicare       divorced
# 4                                  deceased  medicare       divorced
# 5  rehabilitation or distinct part hospital  medicare        unknown
# 6                  skilled nursing facility  medicare        married
# 7                  skilled nursing facility  medicare       divorced
# 8  rehabilitation or distinct part hospital  medicare        widowed
# 9                  skilled nursing facility  medicare        married
#
#                                            diagnosis has_chartevents_data  \
# 0                                             sepsis                  yes
# 1                                        hepatitis b                  yes
# 2                                             sepsis                  yes
# 3                                   humeral fracture                  yes
# 4                                alcoholic hepatitis                  yes
# 5                                             stroke                  yes
# 6  coronary artery bypass graft with mitral valve...                  yes
# 7                                 syncope; telemetry                  yes
# 8                            right humerous fracture                  yes
# 9                 renal failure-syncope-hyperkalemia                  yes
#
#   readmitted_within_30_days  ... vital_mean_223762  vital_mean_224690  \
# 0                        no  ...         37.443333               20.0
# 1                        no  ...         37.443333               20.0
# 2                        no  ...         37.443333               20.0
# 3                        no  ...         37.443333               20.0
# 4                        no  ...         37.443333               20.0
# 5                        no  ...         37.443333               20.0
# 6                        no  ...         37.443333               20.0
# 7                        no  ...         37.443333               20.0
# 8                        no  ...         37.443333               20.0
# 9                        no  ...         37.443333               20.0
#
#    vital_last_220045  vital_last_220179  vital_last_223762  vital_last_224690  \
# 0               79.5              115.0               36.3               18.0
# 1               79.5              115.0               36.3               18.0
# 2               79.5              115.0               36.3               18.0
# 3               79.5              115.0               36.3               18.0
# 4               79.5              115.0               36.3               18.0
# 5               79.5              115.0               36.3               18.0
# 6               79.5              115.0               36.3               18.0
# 7               79.5              115.0               36.3               18.0
# 8               79.5              115.0               36.3               18.0
# 9               79.5              115.0               36.3               18.0
#
#    prior_admissions   length_of_stay_label  \
# 0               0.0    long stay of 9 days
# 1               0.0   long stay of 14 days
# 2               0.0   short stay of 3 days
# 3               0.0    long stay of 8 days
# 4               0.0   short stay of 1 days
# 5               0.0  medium stay of 7 days
# 6               0.0   long stay of 12 days
# 7               0.0   long stay of 10 days
# 8               0.0   long stay of 13 days
# 9               0.0  medium stay of 4 days
#
#                           medication_diversity_label  \
# 0  moderate medication diversity of 34 unique med...
# 1   low medication diversity of 0 unique medications
# 2  low medication diversity of 20 unique medications
# 3  high medication diversity of 52 unique medicat...
# 4  moderate medication diversity of 32 unique med...
# 5  low medication diversity of 26 unique medications
# 6  moderate medication diversity of 45 unique med...
# 7  moderate medication diversity of 32 unique med...
# 8  moderate medication diversity of 30 unique med...
# 9  low medication diversity of 21 unique medications
#
#           emergency_duration_label
# 0  moderate duration of 6.28 hours
# 1                             none
# 2                             none
# 3  moderate duration of 7.62 hours
# 4                             none
# 5  moderate duration of 6.67 hours
# 6                             none
# 7  moderate duration of 5.78 hours
# 8  moderate duration of 5.73 hours
# 9  moderate duration of 7.90 hours
#
# [10 rows x 32 columns]

# %%
# Function to format medication diversity label
def format_medication_diversity_label(label):
    parts = label.split()
    diversity_count = int(parts[4])
    if diversity_count == 0:
        return "none"
    else:
        return f"{parts[0]} {parts[1]} {parts[2]} of {diversity_count} unique medications"

# Apply the function to update the column
balanced_data['medication_diversity_label'] = balanced_data['medication_diversity_label'].apply(format_medication_diversity_label)

# Display a few rows to verify the result
print(balanced_data['medication_diversity_label'].head())
# Out:
# 0    moderate medication diversity of 34 unique med...
# 1                                                 none
# 2    low medication diversity of 20 unique medications
# 3    high medication diversity of 52 unique medicat...
# 4    moderate medication diversity of 32 unique med...
# Name: medication_diversity_label, dtype: object

# %%
balanced_data.head(10)
# Out:
#    subject_id   hadm_id admission_type  \
# 0     10006.0  142345.0      emergency
# 1     10011.0  105331.0      emergency
# 2     10013.0  165520.0      emergency
# 3     10017.0  199207.0      emergency
# 4     10019.0  177759.0      emergency
# 5     10026.0  103770.0      emergency
# 6     10027.0  199395.0       elective
# 7     10029.0  132349.0      emergency
# 8     10032.0  140372.0      emergency
# 9     10033.0  157235.0      emergency
#
#                                   admission_location  \
# 0                           emergency room admission
# 1  transfer from another hospital or external fac...
# 2  transfer from another hospital or external fac...
# 3                           emergency room admission
# 4  transfer from another hospital or external fac...
# 5                           emergency room admission
# 6               physician referral / normal delivery
# 7                           emergency room admission
# 8                           emergency room admission
# 9                           emergency room admission
#
#                          discharge_location insurance marital_status  \
# 0                          home health care  medicare      separated
# 1                                  deceased   private         single
# 2                                  deceased  medicare        unknown
# 3                  skilled nursing facility  medicare       divorced
# 4                                  deceased  medicare       divorced
# 5  rehabilitation or distinct part hospital  medicare        unknown
# 6                  skilled nursing facility  medicare        married
# 7                  skilled nursing facility  medicare       divorced
# 8  rehabilitation or distinct part hospital  medicare        widowed
# 9                  skilled nursing facility  medicare        married
#
#                                            diagnosis has_chartevents_data  \
# 0                                             sepsis                  yes
# 1                                        hepatitis b                  yes
# 2                                             sepsis                  yes
# 3                                   humeral fracture                  yes
# 4                                alcoholic hepatitis                  yes
# 5                                             stroke                  yes
# 6  coronary artery bypass graft with mitral valve...                  yes
# 7                                 syncope; telemetry                  yes
# 8                            right humerous fracture                  yes
# 9                 renal failure-syncope-hyperkalemia                  yes
#
#   readmitted_within_30_days  ... vital_mean_223762  vital_mean_224690  \
# 0                        no  ...         37.443333               20.0
# 1                        no  ...         37.443333               20.0
# 2                        no  ...         37.443333               20.0
# 3                        no  ...         37.443333               20.0
# 4                        no  ...         37.443333               20.0
# 5                        no  ...         37.443333               20.0
# 6                        no  ...         37.443333               20.0
# 7                        no  ...         37.443333               20.0
# 8                        no  ...         37.443333               20.0
# 9                        no  ...         37.443333               20.0
#
#    vital_last_220045  vital_last_220179  vital_last_223762  vital_last_224690  \
# 0               79.5              115.0               36.3               18.0
# 1               79.5              115.0               36.3               18.0
# 2               79.5              115.0               36.3               18.0
# 3               79.5              115.0               36.3               18.0
# 4               79.5              115.0               36.3               18.0
# 5               79.5              115.0               36.3               18.0
# 6               79.5              115.0               36.3               18.0
# 7               79.5              115.0               36.3               18.0
# 8               79.5              115.0               36.3               18.0
# 9               79.5              115.0               36.3               18.0
#
#    prior_admissions   length_of_stay_label  \
# 0               0.0    long stay of 9 days
# 1               0.0   long stay of 14 days
# 2               0.0   short stay of 3 days
# 3               0.0    long stay of 8 days
# 4               0.0   short stay of 1 days
# 5               0.0  medium stay of 7 days
# 6               0.0   long stay of 12 days
# 7               0.0   long stay of 10 days
# 8               0.0   long stay of 13 days
# 9               0.0  medium stay of 4 days
#
#                           medication_diversity_label  \
# 0  moderate medication diversity of 34 unique med...
# 1                                               none
# 2  low medication diversity of 20 unique medications
# 3  high medication diversity of 52 unique medicat...
# 4  moderate medication diversity of 32 unique med...
# 5  low medication diversity of 26 unique medications
# 6  moderate medication diversity of 45 unique med...
# 7  moderate medication diversity of 32 unique med...
# 8  moderate medication diversity of 30 unique med...
# 9  low medication diversity of 21 unique medications
#
#           emergency_duration_label
# 0  moderate duration of 6.28 hours
# 1                             none
# 2                             none
# 3  moderate duration of 7.62 hours
# 4                             none
# 5  moderate duration of 6.67 hours
# 6                             none
# 7  moderate duration of 5.78 hours
# 8  moderate duration of 5.73 hours
# 9  moderate duration of 7.90 hours
#
# [10 rows x 32 columns]

# %%
# Function to format prior admissions
def format_prior_admissions(count):
    if count == 0:
        return "no"
    else:
        return f"{count} times"

# Apply the function to update the column
balanced_data['prior_admissions'] = balanced_data['prior_admissions'].apply(format_prior_admissions)

# Display a few rows to verify the result
print(balanced_data['prior_admissions'].head())
# Out:
# 0    no
# 1    no
# 2    no
# 3    no
# 4    no
# Name: prior_admissions, dtype: object

# %%
balanced_data.head(20)
# Out:
#     subject_id   hadm_id admission_type  \
# 0      10006.0  142345.0      emergency
# 1      10011.0  105331.0      emergency
# 2      10013.0  165520.0      emergency
# 3      10017.0  199207.0      emergency
# 4      10019.0  177759.0      emergency
# 5      10026.0  103770.0      emergency
# 6      10027.0  199395.0       elective
# 7      10029.0  132349.0      emergency
# 8      10032.0  140372.0      emergency
# 9      10033.0  157235.0      emergency
# 10     10035.0  110244.0       elective
# 11     10036.0  189483.0      emergency
# 12     10038.0  111115.0      emergency
# 13     10040.0  157839.0      emergency
# 14     10042.0  148562.0      emergency
# 15     10043.0  168674.0      emergency
# 16     10044.0  124073.0      emergency
# 17     10045.0  126949.0      emergency
# 18     10046.0  133110.0      emergency
# 19     10056.0  100375.0      emergency
#
#                                    admission_location  \
# 0                            emergency room admission
# 1   transfer from another hospital or external fac...
# 2   transfer from another hospital or external fac...
# 3                            emergency room admission
# 4   transfer from another hospital or external fac...
# 5                            emergency room admission
# 6                physician referral / normal delivery
# 7                            emergency room admission
# 8                            emergency room admission
# 9                            emergency room admission
# 10               physician referral / normal delivery
# 11                           emergency room admission
# 12                           emergency room admission
# 13  transfer from another hospital or external fac...
# 14  transfer from another hospital or external fac...
# 15                           emergency room admission
# 16                           emergency room admission
# 17                           emergency room admission
# 18                           emergency room admission
# 19  transfer from another hospital or external fac...
#
#                           discharge_location insurance     marital_status  \
# 0                           home health care  medicare          separated
# 1                                   deceased   private             single
# 2                                   deceased  medicare            unknown
# 3                   skilled nursing facility  medicare           divorced
# 4                                   deceased  medicare           divorced
# 5   rehabilitation or distinct part hospital  medicare            unknown
# 6                   skilled nursing facility  medicare            married
# 7                   skilled nursing facility  medicare           divorced
# 8   rehabilitation or distinct part hospital  medicare            widowed
# 9                   skilled nursing facility  medicare            married
# 10                                      home  medicare            married
# 11                                  deceased  medicare            married
# 12                  skilled nursing facility  medicare            widowed
# 13  rehabilitation or distinct part hospital  medicare            unknown
# 14                          home health care  medicare            unknown
# 15                  skilled nursing facility  medicare            unknown
# 16                                      home  medicare  unknown (default)
# 17                                  deceased  medicare            married
# 18  rehabilitation or distinct part hospital  medicaid             single
# 19                  skilled nursing facility  medicare  unknown (default)
#
#                                             diagnosis has_chartevents_data  \
# 0                                              sepsis                  yes
# 1                                         hepatitis b                  yes
# 2                                              sepsis                  yes
# 3                                    humeral fracture                  yes
# 4                                 alcoholic hepatitis                  yes
# 5                                              stroke                  yes
# 6   coronary artery bypass graft with mitral valve...                  yes
# 7                                  syncope; telemetry                  yes
# 8                             right humerous fracture                  yes
# 9                  renal failure-syncope-hyperkalemia                  yes
# 10     pre hydration; recurrent left carotid stenosis                  yes
# 11                                             sepsis                  yes
# 12                                  failure to thrive                  yes
# 13                   catheterization; pulmonary edema                  yes
# 14                                    unstable angina                  yes
# 15                               respiratory distress                  yes
# 16              brain metastasis; metastatic melanoma                  yes
# 17                                              fever                  yes
# 18                                   brain metastases                  yes
# 19                                             sepsis                  yes
#
#    readmitted_within_30_days  ... vital_mean_223762  vital_mean_224690  \
# 0                         no  ...         37.443333               20.0
# 1                         no  ...         37.443333               20.0
# 2                         no  ...         37.443333               20.0
# 3                         no  ...         37.443333               20.0
# 4                         no  ...         37.443333               20.0
# 5                         no  ...         37.443333               20.0
# 6                         no  ...         37.443333               20.0
# 7                         no  ...         37.443333               20.0
# 8                         no  ...         37.443333               20.0
# 9                         no  ...         37.443333               20.0
# 10                        no  ...         37.443333               20.0
# 11                        no  ...         37.443333               20.0
# 12                        no  ...         37.443333               20.0
# 13                        no  ...         37.443333               20.0
# 14                        no  ...         37.443333               20.0
# 15                        no  ...         37.443333               20.0
# 16                        no  ...         37.443333               20.0
# 17                        no  ...         37.443333               20.0
# 18                        no  ...         37.443333               20.0
# 19                        no  ...         37.443333               20.0
#
#     vital_last_220045  vital_last_220179  vital_last_223762  \
# 0                79.5              115.0               36.3
# 1                79.5              115.0               36.3
# 2                79.5              115.0               36.3
# 3                79.5              115.0               36.3
# 4                79.5              115.0               36.3
# 5                79.5              115.0               36.3
# 6                79.5              115.0               36.3
# 7                79.5              115.0               36.3
# 8                79.5              115.0               36.3
# 9                79.5              115.0               36.3
# 10               79.5              115.0               36.3
# 11               79.5              115.0               36.3
# 12               79.5              115.0               36.3
# 13               79.5              115.0               36.3
# 14               79.5              115.0               36.3
# 15               79.5              115.0               36.3
# 16               79.5              115.0               36.3
# 17               79.5              115.0               36.3
# 18               79.5              115.0               36.3
# 19               79.5              115.0               36.3
#
#     vital_last_224690  prior_admissions   length_of_stay_label  \
# 0                18.0                no    long stay of 9 days
# 1                18.0                no   long stay of 14 days
# 2                18.0                no   short stay of 3 days
# 3                18.0                no    long stay of 8 days
# 4                18.0                no   short stay of 1 days
# 5                18.0                no  medium stay of 7 days
# 6                18.0                no   long stay of 12 days
# 7                18.0                no   long stay of 10 days
# 8                18.0                no   long stay of 13 days
# 9                18.0                no  medium stay of 4 days
# 10               18.0                no  medium stay of 4 days
# 11               18.0                no   short stay of 2 days
# 12               18.0                no   long stay of 12 days
# 13               18.0                no  medium stay of 4 days
# 14               18.0                no   long stay of 11 days
# 15               18.0                no   long stay of 13 days
# 16               18.0                no    long stay of 9 days
# 17               18.0                no  medium stay of 7 days
# 18               18.0                no   long stay of 11 days
# 19               18.0                no  medium stay of 5 days
#
#                            medication_diversity_label  \
# 0   moderate medication diversity of 34 unique med...
# 1                                                none
# 2   low medication diversity of 20 unique medications
# 3   high medication diversity of 52 unique medicat...
# 4   moderate medication diversity of 32 unique med...
# 5   low medication diversity of 26 unique medications
# 6   moderate medication diversity of 45 unique med...
# 7   moderate medication diversity of 32 unique med...
# 8   moderate medication diversity of 30 unique med...
# 9   low medication diversity of 21 unique medications
# 10  low medication diversity of 21 unique medications
# 11  low medication diversity of 18 unique medications
# 12  moderate medication diversity of 35 unique med...
# 13  moderate medication diversity of 32 unique med...
# 14  moderate medication diversity of 42 unique med...
# 15  moderate medication diversity of 40 unique med...
# 16  moderate medication diversity of 34 unique med...
# 17  high medication diversity of 65 unique medicat...
# 18                                               none
# 19  low medication diversity of 26 unique medications
#
#            emergency_duration_label
# 0   moderate duration of 6.28 hours
# 1                              none
# 2                              none
# 3   moderate duration of 7.62 hours
# 4                              none
# 5   moderate duration of 6.67 hours
# 6                              none
# 7   moderate duration of 5.78 hours
# 8   moderate duration of 5.73 hours
# 9   moderate duration of 7.90 hours
# 10                             none
# 11  moderate duration of 6.60 hours
# 12  moderate duration of 6.62 hours
# 13                             none
# 14                             none
# 15     short duration of 3.92 hours
# 16      long duration of 9.52 hours
# 17  moderate duration of 7.15 hours
# 18  moderate duration of 6.10 hours
# 19                             none
#
# [20 rows x 32 columns]

# %%
balanced_data.shape
# Out:
# (236, 32)

# %%
# Check for duplicate rows in the entire DataFrame
duplicates = balanced_data[balanced_data.duplicated()]

# Count of duplicate rows
print("Number of duplicate rows:", duplicates.shape[0])
# Out:
# Number of duplicate rows: 0

# %%
# Save cleaned dataset to CSV
balanced_data.to_csv('clean_balance_data.csv', index=False)
